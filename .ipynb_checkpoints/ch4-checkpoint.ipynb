# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %%
img_rows = 28
img_cols = 28
channels = 1
img_shape = (img_rows, img_cols, channels)

z_dim = 100

# %% [markdown]
# ### Generator

# %% [markdown]
# ConvNet과 반대로 벡터를 받아 크기를 늘려서 이미지 생성(Transposed Convolution 사용)

# %% [markdown]
# ![image.png](attachment:ec2aacd3-84ff-4eda-9118-a236cc630515.png)

# %% [markdown]
# 1. Random noise vector를 fully-connected layer를 통해 7x7x256의 tensor로 변환
# 2. Transposed Convolution을 이용해 7x7x256 -> 14x14x128 tensor로 변환
# 3. BN, LeakyReLU 적용
# 4. Transposed Convolution을 이용해 14x14x128 -> 14x14x64 tensor로 변환, stride=1로 지정하여 너비와 높이 변환 X
# 5. BN, LeakyReLU 적용
# 6. Transposed Convolution을 이용해 14x14x64 -> 28x28x1 출력이미지 크기로 변환
# 7. tanh 적용

# %%
def build_generator(z_dim):
    model = Sequential()
    model.add(Dense(256*7*7, input_dim = z_dim))
    model.add(Reshape((7, 7, 256)))
    model.add(Conv2DTranspose(128, kernel_size = 3, strides = 2, padding = 'same')) 
    # padding을 ‘same’으로 설정 했을 때, Output = Input x stride
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha = 0.01))
    model.add(Conv2DTranspose(64, kernel_size = 3, strides = 1, padding = 'same')) 
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha = 0.01))
    model.add(Conv2DTranspose(1, kernel_size = 3, strides = 2, padding = 'same'))
    model.add(Activation('tanh'))
    
    return model

# %%
generator = build_generator(z_dim)
generator.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 12544)             1266944
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 14, 14, 128)       295040
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 14, 14, 64)        73792
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 28, 28, 1)         577
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 1,637,121
# Trainable params: 1,636,737
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# ### Discriminator

# %% [markdown]
# ConvNet을 통해 입력 이미지의 진짜 여부를 나타냄

# %% [markdown]
# ![image.png](attachment:af41a08c-3fcc-436d-938a-bb8e337d585b.png)

# %% [markdown]
# 1. Convolution을 사용해 28x28x1 -> 14x14x32 tensor로 변환
# 2. LeakyReLU 적용
# 3. Convolution을 사용해 14x14x32 -> 7x7x64 tensor로 변환
# 4. LeakyReLU 적용
# 5. Convolution을 사용해 7x7x64 -> 4x4x128 tensor로 변환
# 6. LeakyReLU 적용
# 7. 4x4x128 -> 4x4x128 = 2048 vector로 flatten
# 8. Fully-connected layer와 sigmoid를 사용해 확률 계산

# %%
def build_discriminator(img_shape):
    model = Sequential()
    model.add(Conv2D(32, kernel_size = 3, strides = 2, input_shape = img_shape, padding = 'same'))
    model.add(LeakyReLU(alpha = 0.01))
    model.add(Conv2D(64, kernel_size = 3, strides = 2,  padding = 'same'))
    model.add(LeakyReLU(alpha = 0.01))
    model.add(Conv2D(128, kernel_size = 3, strides = 2,  padding = 'same'))
    model.add(LeakyReLU(alpha = 0.01))
    model.add(Flatten())
    model.add(Dense(1, activation = 'sigmoid'))
    
    return model

# %% [markdown]
# GAN의 고질적인 문제인 모드 붕괴(mode collapse)에 빠져 BN 제거

# %%
discriminator = build_discriminator(img_shape)
discriminator.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 14, 14, 32)        320
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 2049
# =================================================================
# Total params: 94,721
# Trainable params: 94,721
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Build & Training

# %%
def build_gan(generator, discriminator):
    model = Sequential()
    model.add(generator)
    model.add(discriminator)
    return model

# %%
discriminator = build_discriminator(img_shape)
discriminator.compile(loss = 'binary_crossentropy', optimizer = Adam(), metrics = ['accuracy'])

generator = build_generator(z_dim)

discriminator.trainable = False

gan = build_gan(generator, discriminator) #생성자를 훈련하기 위해 동결한 판별자로 GAN 컴파일
gan.compile(loss = 'binary_crossentropy', optimizer = Adam())

# %%
losses = []
accuracies = []
iteration_checkpoints = []

def train(iterations, batch_size, sample_interval):
    
    (X_train, _), (_, _) = mnist.load_data()
    
    X_train = X_train / 127.5 -1.0
    X_train = np.expand_dims(X_train, axis = 3)
    
    real = np.ones((batch_size, 1)) #진짜 이미지 레이블 1
    fake = np.zeros((batch_size, 1)) #가짜 이미지 레이블 0
    
    for iteration in range(iterations):
        idx = np.random.randint(0, X_train.shape[0], batch_size) #진짜 이미지에서 랜덤 배치
        imgs = X_train[idx]
        
        z = np.random.normal(0, 1, (batch_size, 100)) #가짜 이미지 배치 생성
        gen_imgs = generator.predict(z)
        
        d_loss_real = discriminator.train_on_batch(imgs, real) #판별자 훈련
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)
        d_loss, accuracy = 0.5 * np.add(d_loss_real, d_loss_fake)
        
        z = np.random.normal(0, 1, (batch_size, 100)) #가짜 이미지 배치 생성
        gen_imgs = generator.predict(z) 
        # 위 두줄은 왜 필요??
        
        g_loss = gan.train_on_batch(z, real) #생성자 훈련
        
        if (iteration + 1) %  sample_interval == 0:
            losses.append((d_loss, g_loss)) #훈련 종료 후 그래프 그리기 위한 값 저장
            accuracies.append(100.0 * accuracy)
            iteration_checkpoints.append(iteration + 1)
            
            print("%d [D 손실: %f, 정확도: : %.2f%%] [G 손실: %f]" %(iteration +1, d_loss, 100.0 * accuracy, g_loss))
            
            sample_images(generator) #생성된 이미지 샘플 출력

# %%
def sample_images(generator, image_grid_rows = 4, image_grid_columns = 4):
    z = np.random.normal(0, 1, (image_grid_rows * image_grid_columns, z_dim)) #random noise vector
    
    gen_imgs = generator.predict(z)
    gen_imgs = 0.5 * gen_imgs + 0.5 #이미지 픽셀 값을 0~1 범위로 조정
    
    fig, axs = plt.subplots(image_grid_rows, image_grid_columns, figsize = (4, 4), sharey = True, sharex = True) #이미지 그리드 설정
    
    cnt = 0
    for i in range(image_grid_rows):
        for j in range(image_grid_columns):
            axs[i, j].imshow(gen_imgs[cnt, :, :, 0], cmap = 'gray') #이미지 그리드 출력
            axs[i, j].axis('off')
            cnt += 1

# %%
iterations = 20000
batch_size = 128
sample_interval = 1000

# %%
train(iterations, batch_size, sample_interval)
# Out:
# 1000 [D 손실: 0.100439, 정확도: : 98.83%] [G 손실: 3.129097]
# 2000 [D 손실: 0.057360, 정확도: : 98.44%] [G 손실: 5.939219]
# 3000 [D 손실: 0.103487, 정확도: : 96.48%] [G 손실: 4.919142]
# 4000 [D 손실: 0.260098, 정확도: : 87.89%] [G 손실: 3.104785]
# 5000 [D 손실: 0.168369, 정확도: : 91.80%] [G 손실: 3.484136]
# 6000 [D 손실: 0.336395, 정확도: : 84.38%] [G 손실: 3.511373]
# 7000 [D 손실: 0.190580, 정확도: : 92.19%] [G 손실: 3.496081]
# 8000 [D 손실: 0.322650, 정확도: : 87.89%] [G 손실: 3.659892]
# 9000 [D 손실: 0.336182, 정확도: : 87.89%] [G 손실: 3.527567]
# 10000 [D 손실: 0.387075, 정확도: : 83.59%] [G 손실: 3.005302]
# 11000 [D 손실: 0.545962, 정확도: : 74.22%] [G 손실: 2.947698]
# 12000 [D 손실: 0.274596, 정확도: : 86.72%] [G 손실: 4.054441]
# 13000 [D 손실: 0.513598, 정확도: : 78.52%] [G 손실: 2.514453]
# 14000 [D 손실: 0.285879, 정확도: : 89.06%] [G 손실: 3.699908]
# 15000 [D 손실: 0.397334, 정확도: : 83.20%] [G 손실: 3.389789]
# 16000 [D 손실: 0.207921, 정확도: : 91.80%] [G 손실: 3.524920]
# 17000 [D 손실: 0.302509, 정확도: : 86.72%] [G 손실: 2.786230]
# 18000 [D 손실: 0.237181, 정확도: : 90.23%] [G 손실: 3.246032]
# 19000 [D 손실: 0.325968, 정확도: : 86.72%] [G 손실: 3.010788]
# 20000 [D 손실: 0.307691, 정확도: : 88.28%] [G 손실: 3.653159]

# %%
losses = np.array(losses)

# Plot training losses for Discriminator and Generator
plt.figure(figsize=(15, 5))
plt.plot(iteration_checkpoints, losses.T[0], label="Discriminator loss")
plt.plot(iteration_checkpoints, losses.T[1], label="Generator loss")

plt.xticks(iteration_checkpoints, rotation=90)

plt.title("Training Loss")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.legend()

# %%
accuracies = np.array(accuracies)

# Plot Discriminator accuracy
plt.figure(figsize=(15, 5))
plt.plot(iteration_checkpoints, accuracies, label="Discriminator accuracy")

plt.xticks(iteration_checkpoints, rotation=90)
plt.yticks(range(0, 100, 5))

plt.title("Discriminator Accuracy")
plt.xlabel("Iteration")
plt.ylabel("Accuracy (%)")
plt.legend()
